# %%
import pandas as pd
from ephesus.sentence import load_model, return_label
from ephesus.nlp import TrainerNGAP
from ephesus.data import get_data_json, get_data_targets_json

# %% [markdown]
# # try out the model

# %%
path = "../models/model_v2/model-best"

model = load_model(path)

# %%
sentence = "prise de sang faite ce jour à 18h"

words = return_label(sentence, model)

# %%
words
# Out:
# [('prise de sang', 'Treatment'), ('ce jour', 'Date'), ('18h', 'Time')]

# %% [markdown]
# # apply the model to get the treatments

# %%
df = get_data_json()
df.head()
# Out:
#                                              fichier  \
# 0  3e7ffb67-8872-4172-bf18-4fe338ecae3f_64e118fc-...
# 1  2d035c4b-cdfa-4982-87dc-916fe07a0824_50e8d80a-...
# 2  f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_3ab44a1b-...
# 3  a5050600-95ef-43d8-a5fa-a57c791bf843_2af70417-...
# 4  9f980dcf-b431-4e67-876f-2b8e288b7900_777f3b22-...
#
#                                          translation
# 0  Nouvelle ordonnance pour madame Vilain, valabl...
# 1  Prise de sang réalisée au domicile, ce jour, l...
# 2  Prise de sang réalisée le 12 mai puis le 9 jui...
# 3  Injection intramusculaire cet après-midi, pas ...
# 4  Test PCR remboursable fait le 8 février à 11h1...

# %%
df["entities"] = df["translation"].apply(lambda x: return_label(x, model))
df.head()
# Out:
#                                              fichier  \
# 0  3e7ffb67-8872-4172-bf18-4fe338ecae3f_64e118fc-...
# 1  2d035c4b-cdfa-4982-87dc-916fe07a0824_50e8d80a-...
# 2  f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_3ab44a1b-...
# 3  a5050600-95ef-43d8-a5fa-a57c791bf843_2af70417-...
# 4  9f980dcf-b431-4e67-876f-2b8e288b7900_777f3b22-...
#
#                                          translation  \
# 0  Nouvelle ordonnance pour madame Vilain, valabl...
# 1  Prise de sang réalisée au domicile, ce jour, l...
# 2  Prise de sang réalisée le 12 mai puis le 9 jui...
# 3  Injection intramusculaire cet après-midi, pas ...
# 4  Test PCR remboursable fait le 8 février à 11h1...
#
#                                             entities
# 0  [(valable 6 mois, Duration), (domicile, Locati...
# 1  [(Prise de sang, Treatment), (domicile, Locati...
# 2  [(Prise de sang, Treatment), (12 mai, Date), (...
# 3  [(Injection intramusculaire, Treatment), (cet ...
# 4  [(Test PCR, Treatment), (8 février, Date), (11...

# %%
df["entities"][0]
# Out:
# [('valable 6 mois', 'Duration'),
#  ('domicile', 'Location'),
#  ('une fois par mois', 'Frequency'),
#  ('prise de sang', 'Treatment'),
#  ('prise de sang', 'Treatment'),
#  ('27 juillet', 'Date'),
#  ('26 octobre', 'Date'),
#  ('30 novembre', 'Date'),
#  ('28 décembre', 'Date'),
#  ('11h', 'Time')]

# %%
def keep_treatment_only(entities):
    return [entity[0] for entity in entities if entity[1] == "Treatment"]

# %%
df["treatments"] = df["entities"].apply(keep_treatment_only)
df.head()
# Out:
#                                              fichier  \
# 0  3e7ffb67-8872-4172-bf18-4fe338ecae3f_64e118fc-...
# 1  2d035c4b-cdfa-4982-87dc-916fe07a0824_50e8d80a-...
# 2  f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_3ab44a1b-...
# 3  a5050600-95ef-43d8-a5fa-a57c791bf843_2af70417-...
# 4  9f980dcf-b431-4e67-876f-2b8e288b7900_777f3b22-...
#
#                                          translation  \
# 0  Nouvelle ordonnance pour madame Vilain, valabl...
# 1  Prise de sang réalisée au domicile, ce jour, l...
# 2  Prise de sang réalisée le 12 mai puis le 9 jui...
# 3  Injection intramusculaire cet après-midi, pas ...
# 4  Test PCR remboursable fait le 8 février à 11h1...
#
#                                             entities  \
# 0  [(valable 6 mois, Duration), (domicile, Locati...
# 1  [(Prise de sang, Treatment), (domicile, Locati...
# 2  [(Prise de sang, Treatment), (12 mai, Date), (...
# 3  [(Injection intramusculaire, Treatment), (cet ...
# 4  [(Test PCR, Treatment), (8 février, Date), (11...
#
#                        treatments
# 0  [prise de sang, prise de sang]
# 1                 [Prise de sang]
# 2                 [Prise de sang]
# 3     [Injection intramusculaire]
# 4                      [Test PCR]

# %%
df_split = pd.DataFrame(df["treatments"].to_list())
df_split.head()
# Out:
#                            0              1     2     3     4     5     6  \
# 0              prise de sang  prise de sang  None  None  None  None  None
# 1              Prise de sang           None  None  None  None  None  None
# 2              Prise de sang           None  None  None  None  None  None
# 3  Injection intramusculaire           None  None  None  None  None  None
# 4                   Test PCR           None  None  None  None  None  None
#
#       7     8
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None

# %%
df_split["filename"] = df["fichier"]
df_split.head()
# Out:
#                            0              1     2     3     4     5     6  \
# 0              prise de sang  prise de sang  None  None  None  None  None
# 1              Prise de sang           None  None  None  None  None  None
# 2              Prise de sang           None  None  None  None  None  None
# 3  Injection intramusculaire           None  None  None  None  None  None
# 4                   Test PCR           None  None  None  None  None  None
#
#       7     8                                           filename
# 0  None  None  3e7ffb67-8872-4172-bf18-4fe338ecae3f_64e118fc-...
# 1  None  None  2d035c4b-cdfa-4982-87dc-916fe07a0824_50e8d80a-...
# 2  None  None  f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_3ab44a1b-...
# 3  None  None  a5050600-95ef-43d8-a5fa-a57c791bf843_2af70417-...
# 4  None  None  9f980dcf-b431-4e67-876f-2b8e288b7900_777f3b22-...

# %%
df_stack = pd.DataFrame(df_split.set_index("filename").stack()).reset_index().rename(columns={0 : "treatment"})
df_stack.head()
# Out:
#                                             filename  level_1  \
# 0  3e7ffb67-8872-4172-bf18-4fe338ecae3f_64e118fc-...        0
# 1  3e7ffb67-8872-4172-bf18-4fe338ecae3f_64e118fc-...        1
# 2  2d035c4b-cdfa-4982-87dc-916fe07a0824_50e8d80a-...        0
# 3  f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_3ab44a1b-...        0
# 4  a5050600-95ef-43d8-a5fa-a57c791bf843_2af70417-...        0
#
#                    treatment
# 0              prise de sang
# 1              prise de sang
# 2              Prise de sang
# 3              Prise de sang
# 4  Injection intramusculaire

# %% [markdown]
# # now it's time to get the targets

# %%
df_targets = get_data_targets_json()[["fichier", "NGAP_1"]]
df_targets.head()
# Out:
#                                              fichier  NGAP_1
# 0  2d035c4b-cdfa-4982-87dc-916fe07a0824_249f1d30-...     PSG
# 1  2d035c4b-cdfa-4982-87dc-916fe07a0824_019a0add-...    PC19
# 2  55d674cc-3389-4cf6-ab7c-1f1b9fa1b6ed_02a55241-...  TAID19
# 3  9f980dcf-b431-4e67-876f-2b8e288b7900_1a26bbf2-...  TAIC19
# 4  2d035c4b-cdfa-4982-87dc-916fe07a0824_545d42f0-...     PSG

# %%
# clean filename for merge
def clean_filename(filename):
    return filename[:-17] if "translation.json" in filename else filename[:-16]
df_stack["filename_cleaned"] = df_stack["filename"].apply(clean_filename)
df_targets["filename_cleaned"] = df_targets["fichier"].apply(clean_filename)
# merge
df = df_stack.merge(df_targets, how="left", on="filename_cleaned")
df.head()
# Out:
#                                             filename  level_1  \
# 0  3e7ffb67-8872-4172-bf18-4fe338ecae3f_64e118fc-...        0
# 1  3e7ffb67-8872-4172-bf18-4fe338ecae3f_64e118fc-...        1
# 2  2d035c4b-cdfa-4982-87dc-916fe07a0824_50e8d80a-...        0
# 3  f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_3ab44a1b-...        0
# 4  a5050600-95ef-43d8-a5fa-a57c791bf843_2af70417-...        0
#
#                    treatment  \
# 0              prise de sang
# 1              prise de sang
# 2              Prise de sang
# 3              Prise de sang
# 4  Injection intramusculaire
#
#                                     filename_cleaned  \
# 0  3e7ffb67-8872-4172-bf18-4fe338ecae3f_64e118fc-...
# 1  3e7ffb67-8872-4172-bf18-4fe338ecae3f_64e118fc-...
# 2  2d035c4b-cdfa-4982-87dc-916fe07a0824_50e8d80a-...
# 3  f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_3ab44a1b-...
# 4  a5050600-95ef-43d8-a5fa-a57c791bf843_2af70417-...
#
#                                              fichier NGAP_1
# 0  3e7ffb67-8872-4172-bf18-4fe338ecae3f_64e118fc-...    PSG
# 1  3e7ffb67-8872-4172-bf18-4fe338ecae3f_64e118fc-...    PSG
# 2  2d035c4b-cdfa-4982-87dc-916fe07a0824_50e8d80a-...    PSG
# 3  f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_3ab44a1b-...    PSG
# 4  a5050600-95ef-43d8-a5fa-a57c791bf843_2af70417-...     IM

# %%
df = df[["treatment", "NGAP_1"]].rename(columns={"treatment" : "X", "NGAP_1" : "y"})
df.head()
# Out:
#                            X    y
# 0              prise de sang  PSG
# 1              prise de sang  PSG
# 2              Prise de sang  PSG
# 3              Prise de sang  PSG
# 4  Injection intramusculaire   IM

# %% [markdown]
# # now that I added this to the package, I can call TrainerNGAP()

# %%
trainer = TrainerNGAP()

# %%
path = "../models/model_v2/model-best"
trainer.get_training_data(path)

# %%
trainer.train_ngap()
# Out:
# 2022-06-03 16:42:52.506678: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-06-03 16:42:52.506702: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-03 16:42:52.506718: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (think): /proc/driver/nvidia/version does not exist
# 2022-06-03 16:42:52.506907: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# 255/255 [==============================] - 3s 8ms/step - loss: 1.5514 - accuracy: 0.5593 - val_loss: 1.1832 - val_accuracy: 0.6640
# Epoch 2/50
# 255/255 [==============================] - 2s 6ms/step - loss: 1.1454 - accuracy: 0.6527 - val_loss: 1.0684 - val_accuracy: 0.6950
# Epoch 3/50
# 255/255 [==============================] - 2s 6ms/step - loss: 1.0350 - accuracy: 0.6926 - val_loss: 1.0304 - val_accuracy: 0.6583
# Epoch 4/50
# 255/255 [==============================] - 1s 6ms/step - loss: 0.9882 - accuracy: 0.7098 - val_loss: 1.0043 - val_accuracy: 0.7087
# Epoch 5/50
# 255/255 [==============================] - 2s 6ms/step - loss: 0.9526 - accuracy: 0.7177 - val_loss: 0.9979 - val_accuracy: 0.7053
# Epoch 6/50
# 255/255 [==============================] - 1s 6ms/step - loss: 0.9302 - accuracy: 0.7270 - val_loss: 1.0162 - val_accuracy: 0.6583
# Epoch 7/50
# 255/255 [==============================] - 1s 6ms/step - loss: 0.9116 - accuracy: 0.7260 - val_loss: 1.0386 - val_accuracy: 0.6560
# Epoch 8/50
# 255/255 [==============================] - 2s 7ms/step - loss: 0.8955 - accuracy: 0.7339 - val_loss: 1.0258 - val_accuracy: 0.6537
# Epoch 9/50
# 255/255 [==============================] - 2s 7ms/step - loss: 0.8783 - accuracy: 0.7418 - val_loss: 1.0075 - val_accuracy: 0.7018
# Epoch 10/50
# 255/255 [==============================] - 2s 7ms/step - loss: 0.8698 - accuracy: 0.7427 - val_loss: 1.0116 - val_accuracy: 0.7018

# %%
score = trainer.eval_ngap()
score
# Out:
# 45/45 [==============================] - 0s 3ms/step - loss: 1.0545 - accuracy: 0.6920
# 0.6920391321182251

# %%
df_pred = trainer.predict_ngap()
df_pred.head()
# Out:
# 45/45 [==============================] - 0s 2ms/step
#                      X    NGAP   softmax
# 0        [prise, sang]     PSG  0.811144
# 1  [test, antigénique]  TAID19  0.488484
# 2        [prise, sang]     PSG  0.811144
# 3       [pprise, sang]     PSG  0.600769
# 4  [pansement, simple]    PSTA  0.825050
