# %% [markdown]
# # the goal is to create a metric to evaluate the date found by our models

# %%
import pandas as pd
from ephesus.date import get_data_json, get_dates, get_data_targets_json, get_dates_targets

# %%
# get feature sample
sample_size = 30
df_X = get_data_json()
df_X_sample = get_dates(df_X.sample(sample_size).copy())
# get target dates
df_y = get_dates_targets(get_data_targets_json())

# %%
df_X_sample["fichier"].head().to_list()
# Out:
# ['f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_134e5aa4-ce20-421f-a546-ef11f5d30541_translation.json',
#  'b96ad235-2f4f-4236-9aa3-9df85dfcf7cb_1bdc3625-2ecb-4256-a826-0d28e40904d3_translation.json',
#  '9f980dcf-b431-4e67-876f-2b8e288b7900_81e9bb37-df22-4312-bcbe-fd2f32294cee_translation.json',
#  '2d035c4b-cdfa-4982-87dc-916fe07a0824_4aa3c092-e026-4c98-a4a9-5c31c09bc0b4_translation.json',
#  '9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_403bfcb4-8646-4b45-a1a4-06cdb747f8fc_translation.json']

# %%
df_y["fichier"].head().to_list()
# Out:
# ['2d035c4b-cdfa-4982-87dc-916fe07a0824_249f1d30-1a50-42de-a3a6-20c295f770c7_extraction.json',
#  '2d035c4b-cdfa-4982-87dc-916fe07a0824_019a0add-5b4a-4cb9-b999-daeb5e2a54fd_extraction.json',
#  '55d674cc-3389-4cf6-ab7c-1f1b9fa1b6ed_02a55241-ccf4-4f9a-87ac-23e0ac71e576_extraction.json',
#  '9f980dcf-b431-4e67-876f-2b8e288b7900_1a26bbf2-1192-4139-b6fb-cb7fc1c826ce_extraction.json',
#  '2d035c4b-cdfa-4982-87dc-916fe07a0824_545d42f0-5eb0-4eec-987e-49386f952502_extraction.json']

# %%
def clean_filename(filename):
    return filename[:-17] if "translation.json" in filename else filename[:-16]

print(clean_filename('2d035c4b-cdfa-4982-87dc-916fe07a0824_1275c4e7-526e-4736-8e5b-bc95ae00f890_translation.json'))
print(clean_filename('2d035c4b-cdfa-4982-87dc-916fe07a0824_249f1d30-1a50-42de-a3a6-20c295f770c7_extraction.json'))
# Out:
# 2d035c4b-cdfa-4982-87dc-916fe07a0824_1275c4e7-526e-4736-8e5b-bc95ae00f890
# 2d035c4b-cdfa-4982-87dc-916fe07a0824_249f1d30-1a50-42de-a3a6-20c295f770c7

# %%
df_X_sample["filename_cleaned"] = df_X_sample["fichier"].apply(clean_filename)
df_y["filename_cleaned"] = df_y["fichier"].apply(clean_filename)

# %%
df_X_sample["filename_cleaned"].head().to_list()
# Out:
# ['f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_134e5aa4-ce20-421f-a546-ef11f5d30541',
#  'b96ad235-2f4f-4236-9aa3-9df85dfcf7cb_1bdc3625-2ecb-4256-a826-0d28e40904d3',
#  '9f980dcf-b431-4e67-876f-2b8e288b7900_81e9bb37-df22-4312-bcbe-fd2f32294cee',
#  '2d035c4b-cdfa-4982-87dc-916fe07a0824_4aa3c092-e026-4c98-a4a9-5c31c09bc0b4',
#  '9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_403bfcb4-8646-4b45-a1a4-06cdb747f8fc']

# %%
df_y["filename_cleaned"].head().to_list()
# Out:
# ['2d035c4b-cdfa-4982-87dc-916fe07a0824_249f1d30-1a50-42de-a3a6-20c295f770c7',
#  '2d035c4b-cdfa-4982-87dc-916fe07a0824_019a0add-5b4a-4cb9-b999-daeb5e2a54fd',
#  '55d674cc-3389-4cf6-ab7c-1f1b9fa1b6ed_02a55241-ccf4-4f9a-87ac-23e0ac71e576',
#  '9f980dcf-b431-4e67-876f-2b8e288b7900_1a26bbf2-1192-4139-b6fb-cb7fc1c826ce',
#  '2d035c4b-cdfa-4982-87dc-916fe07a0824_545d42f0-5eb0-4eec-987e-49386f952502']

# %%
# merge
df = df_X_sample.merge(df_y, how="left", on="filename_cleaned")

columns_to_keep = [
    "filename_cleaned",
    "words",
    "words_len",
    "CareBeginDate_day_format01",
    "CareBeginDate_day_format02",
    "CareBeginDate_day_format03",
    "CareBeginDate_month_format01",
    "CareBeginDate_month_format02",
    "CareBeginDate_month_format03",
    "CareBeginDate_year_format01",
    "CareBeginDate_year_format02",
    "CareBeginDate_hour_format01",
    "CareBeginDate_hour_format02",
    "CareBeginDate_hour_format03",
    "CareBeginDate_hour_format04",
    "CareBeginDate_hour_format05",
    "CareBeginDate_hour_format06"
]
df = df[columns_to_keep]
df.head()
# Out:
#                                     filename_cleaned  \
# 0  f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_134e5aa4-...
# 1  b96ad235-2f4f-4236-9aa3-9df85dfcf7cb_1bdc3625-...
# 2  9f980dcf-b431-4e67-876f-2b8e288b7900_81e9bb37-...
# 3  2d035c4b-cdfa-4982-87dc-916fe07a0824_4aa3c092-...
# 4  9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_403bfcb4-...
#
#                                                words  words_len  \
# 0  [le premier avril, à 8h15., dans 10 jours, 10 ...          4
# 1                                                 []          0
# 2                                                 []          0
# 3               [le 10 juillet, le 10 juillet à 16h]          2
# 4                             [le 25 septembre à 8h]          1
#
#   CareBeginDate_day_format01 CareBeginDate_day_format02  \
# 0                      jeudi                         01
# 1                      mardi                         22
# 2                      lundi                         24
# 3                   mercredi                         10
# 4                   mercredi                         25
#
#   CareBeginDate_day_format03 CareBeginDate_month_format01  \
# 0                          1                        avril
# 1                         22                         mars
# 2                         24                      janvier
# 3                         10                      juillet
# 4                         25                    septembre
#
#   CareBeginDate_month_format02 CareBeginDate_month_format03  \
# 0                           04                            4
# 1                           03                            3
# 2                           01                            1
# 3                           07                            7
# 4                           09                            9
#
#   CareBeginDate_year_format01 CareBeginDate_year_format02  \
# 0                          21                        2021
# 1                          22                        2022
# 2                          22                        2022
# 3                          19                        2019
# 4                          19                        2019
#
#   CareBeginDate_hour_format01 CareBeginDate_hour_format02  \
# 0                        8h00                          8h
# 1                        7h15                          7h
# 2                       11h00                         11h
# 3                       16h00                         16h
# 4                        8h30                          8h
#
#   CareBeginDate_hour_format03 CareBeginDate_hour_format04  \
# 0                           8                        8h00
# 1                           7                        7h15
# 2                          11                       11h00
# 3                          16                        4h00
# 4                           8                        8h30
#
#   CareBeginDate_hour_format05 CareBeginDate_hour_format06
# 0                          8h                           8
# 1                          7h                           7
# 2                         11h                          11
# 3                          4h                           4
# 4                          8h                           8

# %%
# evaluation : we check if each "CareBeginDate_..." is in one of the dates found in "date_words"

# %%
df.head(20)
# Out:
#                                      filename_cleaned  \
# 0   f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_134e5aa4-...
# 1   b96ad235-2f4f-4236-9aa3-9df85dfcf7cb_1bdc3625-...
# 2   9f980dcf-b431-4e67-876f-2b8e288b7900_81e9bb37-...
# 3   2d035c4b-cdfa-4982-87dc-916fe07a0824_4aa3c092-...
# 4   9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_403bfcb4-...
# 5   55d674cc-3389-4cf6-ab7c-1f1b9fa1b6ed_4ce94c12-...
# 6   f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_790cfe40-...
# 7   2d035c4b-cdfa-4982-87dc-916fe07a0824_3a20d2f2-...
# 8   74b154c1-e265-4cb9-8e71-0c9bbc3dc880_5ea80fbe-...
# 9   2d035c4b-cdfa-4982-87dc-916fe07a0824_0509f8ab-...
# 10  2206f47b-a858-4f23-8696-d10e1050f2d7_3af26627-...
# 11  2d035c4b-cdfa-4982-87dc-916fe07a0824_0b69efec-...
# 12  9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_6ff09926-...
# 13  9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_63c72e95-...
# 14  9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_8f74777d-...
# 15  2d035c4b-cdfa-4982-87dc-916fe07a0824_90d9db3a-...
# 16  f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_34370c0e-...
# 17  74b154c1-e265-4cb9-8e71-0c9bbc3dc880_6f287acf-...
# 18  3e7ffb67-8872-4172-bf18-4fe338ecae3f_0820d1de-...
# 19  55d674cc-3389-4cf6-ab7c-1f1b9fa1b6ed_5bf4f36b-...
#
#                                                 words  words_len  \
# 0   [le premier avril, à 8h15., dans 10 jours, 10 ...          4
# 1                                                  []          0
# 2                                                  []          0
# 3                [le 10 juillet, le 10 juillet à 16h]          2
# 4                              [le 25 septembre à 8h]          1
# 5                                                  []          0
# 6                               [le 8 septembre à 6h]          1
# 7                                      [le 7 février]          1
# 8                      [le lundi le 21 février à 11h]          1
# 9                           [le 1709, 2020 à 6h30, à]          1
# 10                                    [Le 28 février]          1
# 11            [le 27 février 2022 à 19h15 au, 18 ans]          2
# 12                                           [le 23/]          1
# 13                      [lundi et vendredi, le 10/09]          2
# 14                               [2,3,4,5 et 6 avril]          1
# 15                                 [le 4 mars, à 15h]          2
# 16                               [2 février à 10h30.]          1
# 17                    [vendredi, le 3 décembre à 11h]          1
# 18                             [le 29 juin à 8h30 au]          1
# 19                               [le 25 octobre 2020]          1
#
#    CareBeginDate_day_format01 CareBeginDate_day_format02  \
# 0                       jeudi                         01
# 1                       mardi                         22
# 2                       lundi                         24
# 3                    mercredi                         10
# 4                    mercredi                         25
# 5                       lundi                         11
# 6                    mercredi                         08
# 7                    vendredi                         07
# 8                    vendredi                         25
# 9                       jeudi                         17
# 10                      lundi                         28
# 11                   dimanche                         27
# 12                      jeudi                         23
# 13                      lundi                         13
# 14                     samedi                         02
# 15                   vendredi                         04
# 16                   mercredi                         02
# 17                   vendredi                         03
# 18                      lundi                         29
# 19                   dimanche                         25
#
#    CareBeginDate_day_format03 CareBeginDate_month_format01  \
# 0                           1                        avril
# 1                          22                         mars
# 2                          24                      janvier
# 3                          10                      juillet
# 4                          25                    septembre
# 5                          11                      octobre
# 6                           8                    septembre
# 7                           7                      février
# 8                          25                      février
# 9                          17                    septembre
# 10                         28                      février
# 11                         27                      février
# 12                         23                        avril
# 13                         13                    septembre
# 14                          2                        avril
# 15                          4                         mars
# 16                          2                      février
# 17                          3                     décembre
# 18                         29                         juin
# 19                         25                      octobre
#
#    CareBeginDate_month_format02 CareBeginDate_month_format03  \
# 0                            04                            4
# 1                            03                            3
# 2                            01                            1
# 3                            07                            7
# 4                            09                            9
# 5                            10                           10
# 6                            09                            9
# 7                            02                            2
# 8                            02                            2
# 9                            09                            9
# 10                           02                            2
# 11                           02                            2
# 12                           04                            4
# 13                           09                            9
# 14                           04                            4
# 15                           03                            3
# 16                           02                            2
# 17                           12                           12
# 18                           06                            6
# 19                           10                           10
#
#    CareBeginDate_year_format01 CareBeginDate_year_format02  \
# 0                           21                        2021
# 1                           22                        2022
# 2                           22                        2022
# 3                           19                        2019
# 4                           19                        2019
# 5                           21                        2021
# 6                           21                        2021
# 7                           20                        2020
# 8                           22                        2022
# 9                           20                        2020
# 10                          22                        2022
# 11                          22                        2022
# 12                          20                        2020
# 13                          21                        2021
# 14                          22                        2022
# 15                          22                        2022
# 16                          22                        2022
# 17                          21                        2021
# 18                          20                        2020
# 19                          20                        2020
#
#    CareBeginDate_hour_format01 CareBeginDate_hour_format02  \
# 0                         8h00                          8h
# 1                         7h15                          7h
# 2                        11h00                         11h
# 3                        16h00                         16h
# 4                         8h30                          8h
# 5                         8h00                          8h
# 6                         6h30                          6h
# 7                        10h00                         10h
# 8                        11h00                         11h
# 9                         6h30                          6h
# 10                       18h00                         18h
# 11                       19h15                         19h
# 12                       10h45                         10h
# 13                        8h00                          8h
# 14                        8h00                          8h
# 15                       15h00                         15h
# 16                         h00                           h
# 17                       11h00                         11h
# 18                        8h30                          8h
# 19                        8h00                          8h
#
#    CareBeginDate_hour_format03 CareBeginDate_hour_format04  \
# 0                            8                        8h00
# 1                            7                        7h15
# 2                           11                       11h00
# 3                           16                        4h00
# 4                            8                        8h30
# 5                            8                        8h00
# 6                            6                        6h30
# 7                           10                       10h00
# 8                           11                       11h00
# 9                            6                        6h30
# 10                          18                        6h00
# 11                          19                        7h15
# 12                          10                       10h45
# 13                           8                        8h00
# 14                           8                        8h00
# 15                          15                        3h00
# 16                                                   12h00
# 17                          11                       11h00
# 18                           8                        8h30
# 19                           8                        8h00
#
#    CareBeginDate_hour_format05 CareBeginDate_hour_format06
# 0                           8h                           8
# 1                           7h                           7
# 2                          11h                          11
# 3                           4h                           4
# 4                           8h                           8
# 5                           8h                           8
# 6                           6h                           6
# 7                          10h                          10
# 8                          11h                          11
# 9                           6h                           6
# 10                          6h                           6
# 11                          7h                           7
# 12                         10h                          10
# 13                          8h                           8
# 14                          8h                           8
# 15                          3h                           3
# 16                         12h                          12
# 17                         11h                          11
# 18                          8h                           8
# 19                          8h                           8

# %%
df_score = df[["filename_cleaned", "words"]].copy()

df_score["score_day_format01"] = df.apply(lambda x: x["CareBeginDate_day_format01"] in " ".join(x["words"]), axis=1)
df_score["score_day_format02"] = df.apply(lambda x: x["CareBeginDate_day_format02"] in " ".join(x["words"]), axis=1)
df_score["score_day_format03"] = df.apply(lambda x: x["CareBeginDate_day_format03"] in " ".join(x["words"]), axis=1)
df_score["score_month_format01"] = df.apply(lambda x: x["CareBeginDate_month_format01"] in " ".join(x["words"]), axis=1)
df_score["score_month_format02"] = df.apply(lambda x: x["CareBeginDate_month_format02"] in " ".join(x["words"]), axis=1)
df_score["score_month_format03"] = df.apply(lambda x: x["CareBeginDate_month_format03"] in " ".join(x["words"]), axis=1)
df_score["score_year_format01"] = df.apply(lambda x: x["CareBeginDate_year_format01"] in " ".join(x["words"]), axis=1)
df_score["score_year_format02"] = df.apply(lambda x: x["CareBeginDate_year_format02"] in " ".join(x["words"]), axis=1)
df_score["score_hour_format01"] = df.apply(lambda x: x["CareBeginDate_hour_format01"] in " ".join(x["words"]), axis=1)
df_score["score_hour_format02"] = df.apply(lambda x: x["CareBeginDate_hour_format02"] in " ".join(x["words"]), axis=1)
df_score["score_hour_format03"] = df.apply(lambda x: x["CareBeginDate_hour_format03"] in " ".join(x["words"]), axis=1)
df_score["score_hour_format04"] = df.apply(lambda x: x["CareBeginDate_hour_format04"] in " ".join(x["words"]), axis=1)
df_score["score_hour_format05"] = df.apply(lambda x: x["CareBeginDate_hour_format05"] in " ".join(x["words"]), axis=1)
df_score["score_hour_format06"] = df.apply(lambda x: x["CareBeginDate_hour_format06"] in " ".join(x["words"]), axis=1)

df_score["score_day"] = \
    df_score["score_day_format01"] | \
    df_score["score_day_format02"] | \
    df_score["score_day_format03"]

df_score["score_month"] = \
    df_score["score_month_format01"] | \
    df_score["score_month_format02"] | \
    df_score["score_month_format03"]

df_score["score_month"] = \
    df_score["score_month_format01"] | \
    df_score["score_month_format02"] | \
    df_score["score_month_format03"]

df_score["score_year"] = \
    df_score["score_year_format01"] | \
    df_score["score_year_format02"]

df_score["score_hour"] = \
    df_score["score_hour_format01"] | \
    df_score["score_hour_format02"] | \
    df_score["score_hour_format03"] | \
    df_score["score_hour_format04"] | \
    df_score["score_hour_format05"] | \
    df_score["score_hour_format06"]

df_score.head()
# Out:
#                                     filename_cleaned  \
# 0  f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_134e5aa4-...
# 1  b96ad235-2f4f-4236-9aa3-9df85dfcf7cb_1bdc3625-...
# 2  9f980dcf-b431-4e67-876f-2b8e288b7900_81e9bb37-...
# 3  2d035c4b-cdfa-4982-87dc-916fe07a0824_4aa3c092-...
# 4  9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_403bfcb4-...
#
#                                                words  score_day_format01  \
# 0  [le premier avril, à 8h15., dans 10 jours, 10 ...               False
# 1                                                 []               False
# 2                                                 []               False
# 3               [le 10 juillet, le 10 juillet à 16h]               False
# 4                             [le 25 septembre à 8h]               False
#
#    score_day_format02  score_day_format03  score_month_format01  \
# 0               False                True                  True
# 1               False               False                 False
# 2               False               False                 False
# 3                True                True                  True
# 4                True                True                  True
#
#    score_month_format02  score_month_format03  score_year_format01  \
# 0                 False                 False                False
# 1                 False                 False                False
# 2                 False                 False                False
# 3                 False                 False                False
# 4                 False                 False                False
#
#    score_year_format02  score_hour_format01  score_hour_format02  \
# 0                False                False                 True
# 1                False                False                False
# 2                False                False                False
# 3                False                False                 True
# 4                False                False                 True
#
#    score_hour_format03  score_hour_format04  score_hour_format05  \
# 0                 True                False                 True
# 1                False                False                False
# 2                False                False                False
# 3                 True                False                False
# 4                 True                False                 True
#
#    score_hour_format06  score_day  score_month  score_year  score_hour
# 0                 True       True         True       False        True
# 1                False      False        False       False       False
# 2                False      False        False       False       False
# 3                False       True         True       False        True
# 4                 True       True         True       False        True

# %%
df_score["score"] = (df_score["score_day"].astype(int) + df_score["score_month"].astype(int) + \
                     df_score["score_year"].astype(int) + df_score["score_hour"].astype(int) ) / 4

df_score.head()
# Out:
#                                     filename_cleaned  \
# 0  f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_134e5aa4-...
# 1  b96ad235-2f4f-4236-9aa3-9df85dfcf7cb_1bdc3625-...
# 2  9f980dcf-b431-4e67-876f-2b8e288b7900_81e9bb37-...
# 3  2d035c4b-cdfa-4982-87dc-916fe07a0824_4aa3c092-...
# 4  9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_403bfcb4-...
#
#                                                words  score_day_format01  \
# 0  [le premier avril, à 8h15., dans 10 jours, 10 ...               False
# 1                                                 []               False
# 2                                                 []               False
# 3               [le 10 juillet, le 10 juillet à 16h]               False
# 4                             [le 25 septembre à 8h]               False
#
#    score_day_format02  score_day_format03  score_month_format01  \
# 0               False                True                  True
# 1               False               False                 False
# 2               False               False                 False
# 3                True                True                  True
# 4                True                True                  True
#
#    score_month_format02  score_month_format03  score_year_format01  \
# 0                 False                 False                False
# 1                 False                 False                False
# 2                 False                 False                False
# 3                 False                 False                False
# 4                 False                 False                False
#
#    score_year_format02  ...  score_hour_format02  score_hour_format03  \
# 0                False  ...                 True                 True
# 1                False  ...                False                False
# 2                False  ...                False                False
# 3                False  ...                 True                 True
# 4                False  ...                 True                 True
#
#    score_hour_format04  score_hour_format05  score_hour_format06  score_day  \
# 0                False                 True                 True       True
# 1                False                False                False      False
# 2                False                False                False      False
# 3                False                False                False       True
# 4                False                 True                 True       True
#
#    score_month  score_year  score_hour  score
# 0         True       False        True   0.75
# 1        False       False       False   0.00
# 2        False       False       False   0.00
# 3         True       False        True   0.75
# 4         True       False        True   0.75
#
# [5 rows x 21 columns]

# %%
df_score[["words", "score_day", "score_month", "score_year", "score_hour", "score"]].head(20)
# Out:
#                                                 words  score_day  score_month  \
# 0   [le premier avril, à 8h15., dans 10 jours, 10 ...       True         True
# 1                                                  []      False        False
# 2                                                  []      False        False
# 3                [le 10 juillet, le 10 juillet à 16h]       True         True
# 4                              [le 25 septembre à 8h]       True         True
# 5                                                  []      False        False
# 6                               [le 8 septembre à 6h]       True         True
# 7                                      [le 7 février]       True         True
# 8                      [le lundi le 21 février à 11h]      False         True
# 9                           [le 1709, 2020 à 6h30, à]       True         True
# 10                                    [Le 28 février]       True         True
# 11            [le 27 février 2022 à 19h15 au, 18 ans]       True         True
# 12                                           [le 23/]       True        False
# 13                      [lundi et vendredi, le 10/09]       True         True
# 14                               [2,3,4,5 et 6 avril]       True         True
# 15                                 [le 4 mars, à 15h]       True         True
# 16                               [2 février à 10h30.]       True         True
# 17                    [vendredi, le 3 décembre à 11h]       True         True
# 18                             [le 29 juin à 8h30 au]       True         True
# 19                               [le 25 octobre 2020]       True         True
#
#     score_year  score_hour  score
# 0        False        True   0.75
# 1        False       False   0.00
# 2        False       False   0.00
# 3        False        True   0.75
# 4        False        True   0.75
# 5        False       False   0.00
# 6        False        True   0.75
# 7        False       False   0.50
# 8        False        True   0.50
# 9         True        True   1.00
# 10       False       False   0.50
# 11        True        True   1.00
# 12       False       False   0.25
# 13       False       False   0.50
# 14       False       False   0.50
# 15       False        True   0.75
# 16       False        True   0.75
# 17       False        True   0.75
# 18       False        True   0.75
# 19        True       False   0.75

# %%
df_score["filename_cleaned"].to_list()
# Out:
# ['f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_134e5aa4-ce20-421f-a546-ef11f5d30541',
#  'b96ad235-2f4f-4236-9aa3-9df85dfcf7cb_1bdc3625-2ecb-4256-a826-0d28e40904d3',
#  '9f980dcf-b431-4e67-876f-2b8e288b7900_81e9bb37-df22-4312-bcbe-fd2f32294cee',
#  '2d035c4b-cdfa-4982-87dc-916fe07a0824_4aa3c092-e026-4c98-a4a9-5c31c09bc0b4',
#  '9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_403bfcb4-8646-4b45-a1a4-06cdb747f8fc',
#  '55d674cc-3389-4cf6-ab7c-1f1b9fa1b6ed_4ce94c12-e92c-476e-a27b-66e2e10488b9',
#  'f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_790cfe40-a13d-4719-8f94-1b5bc308102c',
#  '2d035c4b-cdfa-4982-87dc-916fe07a0824_3a20d2f2-def7-4abd-a0ec-5e5a8ffb773b',
#  '74b154c1-e265-4cb9-8e71-0c9bbc3dc880_5ea80fbe-1cc2-4b8a-af5e-cc01107c4320',
#  '2d035c4b-cdfa-4982-87dc-916fe07a0824_0509f8ab-e39b-4e8a-ae5c-ab2acd708867',
#  '2206f47b-a858-4f23-8696-d10e1050f2d7_3af26627-bc72-4c41-9254-ae7e257d335c',
#  '2d035c4b-cdfa-4982-87dc-916fe07a0824_0b69efec-9b2c-4514-ba67-4068f637f88e',
#  '9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_6ff09926-7b3e-4c59-bbc0-55a4deeed40e',
#  '9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_63c72e95-72a5-4cf5-b398-c21fd5326db4',
#  '9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_8f74777d-b083-4596-9d56-8170caa964b0',
#  '2d035c4b-cdfa-4982-87dc-916fe07a0824_90d9db3a-9332-4817-93f4-a8776a3e3be7',
#  'f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_34370c0e-b346-4129-a8a2-0b018d6f8446',
#  '74b154c1-e265-4cb9-8e71-0c9bbc3dc880_6f287acf-2d3e-46b9-99eb-505ed3af8dfe',
#  '3e7ffb67-8872-4172-bf18-4fe338ecae3f_0820d1de-eb73-47a2-bd3b-a6a8cd4fe8da',
#  '55d674cc-3389-4cf6-ab7c-1f1b9fa1b6ed_5bf4f36b-34b1-4482-b2cf-05cbf44a4d98',
#  '3e7ffb67-8872-4172-bf18-4fe338ecae3f_2e700fe1-b370-4af9-b011-83229ccbe814',
#  'a5050600-95ef-43d8-a5fa-a57c791bf843_6bdcc550-786f-466f-adf8-b3788f458e11',
#  '2d035c4b-cdfa-4982-87dc-916fe07a0824_63b5f391-eac2-4ddc-8fb8-fbae2ddf2fdd',
#  'a5050600-95ef-43d8-a5fa-a57c791bf843_640e0df3-8065-406e-a7ec-ef71277a9c1c',
#  '978eb126-14a0-46cf-bd27-44b6b77cecb7_3d8714a4-cb38-4695-a54f-46391bfc7bab',
#  'f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_0d8d9d76-6b88-43e1-bf92-40d4cf39205d',
#  '2d035c4b-cdfa-4982-87dc-916fe07a0824_637fe478-2b56-4aab-b1ad-7e028563643a',
#  'b96ad235-2f4f-4236-9aa3-9df85dfcf7cb_390d893c-caee-472e-88f9-e7dfba0dad63',
#  'b96ad235-2f4f-4236-9aa3-9df85dfcf7cb_f3f39a52-a4e1-450c-ad2f-76c8f9a0aa30',
#  'f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_82fe1d11-a21b-4260-9d9c-fc0b388f9220']

# %%
df_score.head(20)
# Out:
#                                      filename_cleaned  \
# 0   f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_134e5aa4-...
# 1   b96ad235-2f4f-4236-9aa3-9df85dfcf7cb_1bdc3625-...
# 2   9f980dcf-b431-4e67-876f-2b8e288b7900_81e9bb37-...
# 3   2d035c4b-cdfa-4982-87dc-916fe07a0824_4aa3c092-...
# 4   9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_403bfcb4-...
# 5   55d674cc-3389-4cf6-ab7c-1f1b9fa1b6ed_4ce94c12-...
# 6   f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_790cfe40-...
# 7   2d035c4b-cdfa-4982-87dc-916fe07a0824_3a20d2f2-...
# 8   74b154c1-e265-4cb9-8e71-0c9bbc3dc880_5ea80fbe-...
# 9   2d035c4b-cdfa-4982-87dc-916fe07a0824_0509f8ab-...
# 10  2206f47b-a858-4f23-8696-d10e1050f2d7_3af26627-...
# 11  2d035c4b-cdfa-4982-87dc-916fe07a0824_0b69efec-...
# 12  9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_6ff09926-...
# 13  9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_63c72e95-...
# 14  9d42ce6f-8537-49a9-a121-c8ae1dc7cda8_8f74777d-...
# 15  2d035c4b-cdfa-4982-87dc-916fe07a0824_90d9db3a-...
# 16  f0caa21b-c11d-40a3-98ec-e2df3d2b9cc4_34370c0e-...
# 17  74b154c1-e265-4cb9-8e71-0c9bbc3dc880_6f287acf-...
# 18  3e7ffb67-8872-4172-bf18-4fe338ecae3f_0820d1de-...
# 19  55d674cc-3389-4cf6-ab7c-1f1b9fa1b6ed_5bf4f36b-...
#
#                                                 words  score_day_format01  \
# 0   [le premier avril, à 8h15., dans 10 jours, 10 ...               False
# 1                                                  []               False
# 2                                                  []               False
# 3                [le 10 juillet, le 10 juillet à 16h]               False
# 4                              [le 25 septembre à 8h]               False
# 5                                                  []               False
# 6                               [le 8 septembre à 6h]               False
# 7                                      [le 7 février]               False
# 8                      [le lundi le 21 février à 11h]               False
# 9                           [le 1709, 2020 à 6h30, à]               False
# 10                                    [Le 28 février]               False
# 11            [le 27 février 2022 à 19h15 au, 18 ans]               False
# 12                                           [le 23/]               False
# 13                      [lundi et vendredi, le 10/09]                True
# 14                               [2,3,4,5 et 6 avril]               False
# 15                                 [le 4 mars, à 15h]               False
# 16                               [2 février à 10h30.]               False
# 17                    [vendredi, le 3 décembre à 11h]                True
# 18                             [le 29 juin à 8h30 au]               False
# 19                               [le 25 octobre 2020]               False
#
#     score_day_format02  score_day_format03  score_month_format01  \
# 0                False                True                  True
# 1                False               False                 False
# 2                False               False                 False
# 3                 True                True                  True
# 4                 True                True                  True
# 5                False               False                 False
# 6                False                True                  True
# 7                False                True                  True
# 8                False               False                  True
# 9                 True                True                 False
# 10                True                True                  True
# 11                True                True                  True
# 12                True                True                 False
# 13               False               False                 False
# 14               False                True                  True
# 15               False                True                  True
# 16               False                True                  True
# 17               False                True                  True
# 18                True                True                  True
# 19                True                True                  True
#
#     score_month_format02  score_month_format03  score_year_format01  \
# 0                  False                 False                False
# 1                  False                 False                False
# 2                  False                 False                False
# 3                  False                 False                False
# 4                  False                 False                False
# 5                  False                 False                False
# 6                  False                 False                False
# 7                  False                 False                False
# 8                  False                  True                False
# 9                   True                  True                 True
# 10                 False                  True                False
# 11                  True                  True                 True
# 12                 False                 False                False
# 13                  True                  True                False
# 14                 False                  True                False
# 15                 False                 False                False
# 16                 False                  True                False
# 17                 False                 False                False
# 18                 False                 False                False
# 19                 False                 False                 True
#
#     score_year_format02  ...  score_hour_format02  score_hour_format03  \
# 0                 False  ...                 True                 True
# 1                 False  ...                False                False
# 2                 False  ...                False                False
# 3                 False  ...                 True                 True
# 4                 False  ...                 True                 True
# 5                 False  ...                False                False
# 6                 False  ...                 True                 True
# 7                 False  ...                False                False
# 8                 False  ...                 True                 True
# 9                  True  ...                 True                 True
# 10                False  ...                False                False
# 11                 True  ...                 True                 True
# 12                False  ...                False                False
# 13                False  ...                False                False
# 14                False  ...                False                False
# 15                False  ...                 True                 True
# 16                False  ...                 True                 True
# 17                False  ...                 True                 True
# 18                False  ...                 True                 True
# 19                 True  ...                False                False
#
#     score_hour_format04  score_hour_format05  score_hour_format06  score_day  \
# 0                 False                 True                 True       True
# 1                 False                False                False      False
# 2                 False                False                False      False
# 3                 False                False                False       True
# 4                 False                 True                 True       True
# 5                 False                False                False      False
# 6                 False                 True                 True       True
# 7                 False                False                False       True
# 8                 False                 True                 True      False
# 9                  True                 True                 True       True
# 10                False                False                False       True
# 11                False                False                 True       True
# 12                False                False                False       True
# 13                False                False                False       True
# 14                False                False                False       True
# 15                False                False                False       True
# 16                False                False                False       True
# 17                False                 True                 True       True
# 18                 True                 True                 True       True
# 19                False                False                False       True
#
#     score_month  score_year  score_hour  score
# 0          True       False        True   0.75
# 1         False       False       False   0.00
# 2         False       False       False   0.00
# 3          True       False        True   0.75
# 4          True       False        True   0.75
# 5         False       False       False   0.00
# 6          True       False        True   0.75
# 7          True       False       False   0.50
# 8          True       False        True   0.50
# 9          True        True        True   1.00
# 10         True       False       False   0.50
# 11         True        True        True   1.00
# 12        False       False       False   0.25
# 13         True       False       False   0.50
# 14         True       False       False   0.50
# 15         True       False        True   0.75
# 16         True       False        True   0.75
# 17         True       False        True   0.75
# 18         True       False        True   0.75
# 19         True        True       False   0.75
#
# [20 rows x 21 columns]
